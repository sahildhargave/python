# %%
import pandas as pd
df=pd.read_csv("./datasets/heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]>

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df[df.Cholesterol>(df.Cholesterol.mean()+3*df.Cholesterol.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 76     130              N      0.0     Flat             1
# 149    125              Y      1.0     Flat             1
# 616    160              N      1.6     Flat             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df1= df[df.Cholesterol<=(df.Cholesterol.mean()+3*df.Cholesterol.std())]
df1.shape
# Out:
# (915, 12)

# %%
df[df.MaxHR>(df.MaxHR.mean()+3*df.MaxHR.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df[df.FastingBS>(df.FastingBS.mean()+3*df.FastingBS.std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df[df.Oldpeak>(df.Oldpeak.mean()+3*df.Oldpeak.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 166   50   M           ASY        140          231          0         ST
# 702   59   M            TA        178          270          0        LVH
# 771   55   M           ASY        140          217          0     Normal
# 791   51   M           ASY        140          298          0     Normal
# 850   62   F           ASY        160          164          0        LVH
# 900   58   M           ASY        114          318          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 166    140              Y      5.0     Flat             1
# 702    145              N      4.2     Down             0
# 771    111              Y      5.6     Down             1
# 791    122              Y      4.2     Flat             1
# 850    145              N      6.2     Down             1
# 900    140              N      4.4     Down             1

# %%
df2=df1[df1.Oldpeak<=(df1.Oldpeak.mean()+3*df1.Oldpeak.std())]
df2.shape
# Out:
# (909, 12)

# %%
df[df.RestingBP>(df.RestingBP.mean()+3*df.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 109    106              N      0.0       Up             0
# 241    142              Y      2.0     Flat             1
# 365    140              Y      1.0     Flat             1
# 399     70              N      0.0     Flat             1
# 592    150              Y      2.0     Down             1
# 732    133              Y      4.0     Down             1
# 759    195              N      0.0       Up             1

# %%
df3=df2[df2.RestingBP<=(df2.RestingBP.mean()+3*df2.RestingBP.std())]
df3.shape
# Out:
# (902, 12)

# %%
df.ChestPainType.unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df.ST_Slope.unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df4=df3.copy()
df4.ExerciseAngina.replace(
	{
		'N':0,
  'Y':1
	},
 inplace=True
)
df4.ST_Slope.replace({
	'Down':1,
 "Flat":2,
 "Up":3
},
                     inplace=True
                     )
df4.RestingECG.replace(
	{
		'Normal':1,
  'ST':2,
  "LVH":3
	},
 inplace=True
)

df4.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40   M           ATA        140          289          0           1
# 1   49   F           NAP        160          180          0           1
# 2   37   M           ATA        130          283          0           2
# 3   48   F           ASY        138          214          0           1
# 4   54   M           NAP        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         3             0
# 1    156               0      1.0         2             1
# 2     98               0      0.0         3             0
# 3    108               1      1.5         2             1
# 4    122               0      0.0         3             0

# %%
df5=pd.get_dummies(df4,drop_first=True)
df5.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  ExerciseAngina  \
# 0   40        140          289          0           1    172               0
# 1   49        160          180          0           1    156               0
# 2   37        130          283          0           2     98               0
# 3   48        138          214          0           1    108               1
# 4   54        150          195          0           1    122               0
#
#    Oldpeak  ST_Slope  HeartDisease  Sex_M  ChestPainType_ATA  \
# 0      0.0         3             0   True               True
# 1      1.0         2             1  False              False
# 2      0.0         3             0   True               True
# 3      1.5         2             1  False              False
# 4      0.0         3             0   True              False
#
#    ChestPainType_NAP  ChestPainType_TA
# 0              False             False
# 1               True             False
# 2              False             False
# 3              False             False
# 4               True             False

# %%
X= df5.drop("HeartDisease",axis='columns')
y=df5.HeartDisease
X.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  ExerciseAngina  \
# 0   40        140          289          0           1    172               0
# 1   49        160          180          0           1    156               0
# 2   37        130          283          0           2     98               0
# 3   48        138          214          0           1    108               1
# 4   54        150          195          0           1    122               0
#
#    Oldpeak  ST_Slope  Sex_M  ChestPainType_ATA  ChestPainType_NAP  \
# 0      0.0         3   True               True              False
# 1      1.0         2  False              False               True
# 2      0.0         3   True               True              False
# 3      1.5         2  False              False              False
# 4      0.0         3   True              False               True
#
#    ChestPainType_TA
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.42896269,  0.46089071,  0.85238015, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        [-0.47545956,  1.5925728 , -0.16132855, ..., -0.4836591 ,
#          1.86750159, -0.22914788],
#        [-1.74679706, -0.10495034,  0.79657967, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        ...,
#        [ 0.37209878, -0.10495034, -0.61703246, ..., -0.4836591 ,
#         -0.53547478, -0.22914788],
#        [ 0.37209878, -0.10495034,  0.35947592, ...,  2.06757196,
#         -0.53547478, -0.22914788],
#        [-1.64085227,  0.3477225 , -0.20782894, ..., -0.4836591 ,
#          1.86750159, -0.22914788]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=30)
X_train.shape
X_test.shape
# Out:
# (181, 13)

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf= RandomForestClassifier()
model_rf.fit(X_train,y_train)
model_rf.score(X_test,y_test)
# Out:
# 0.856353591160221

# %%
X
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0     40        140          289          0           1    172
# 1     49        160          180          0           1    156
# 2     37        130          283          0           2     98
# 3     48        138          214          0           1    108
# 4     54        150          195          0           1    122
# ..   ...        ...          ...        ...         ...    ...
# 913   45        110          264          0           1    132
# 914   68        144          193          1           1    141
# 915   57        130          131          0           1    115
# 916   57        130          236          0           3    174
# 917   38        138          175          0           1    173
#
#      ExerciseAngina  Oldpeak  ST_Slope  Sex_M  ChestPainType_ATA  \
# 0                 0      0.0         3   True               True
# 1                 0      1.0         2  False              False
# 2                 0      0.0         3   True               True
# 3                 1      1.5         2  False              False
# 4                 0      0.0         3   True              False
# ..              ...      ...       ...    ...                ...
# 913               0      1.2         2   True              False
# 914               0      3.4         2   True              False
# 915               1      1.2         2   True              False
# 916               0      0.0         2  False               True
# 917               0      0.0         3   True              False
#
#      ChestPainType_NAP  ChestPainType_TA
# 0                False             False
# 1                 True             False
# 2                False             False
# 3                False             False
# 4                 True             False
# ..                 ...               ...
# 913              False              True
# 914              False             False
# 915              False             False
# 916              False             False
# 917               True             False
#
# [902 rows x 13 columns]

# %%
from sklearn.decomposition import PCA
pca=PCA(0.95)
X_pca=pca.fit_transform(X)
X_pca
# Out:
# array([[ 93.82465373, -29.40099458],
#        [-15.58422331, -14.10909233],
#        [ 83.29606634,  38.6867453 ],
#        ...,
#        [-67.57318721,  17.61319354],
#        [ 40.70458237, -33.38750602],
#        [-19.91368346, -37.29085722]])

# %%
X_train_pca,X_test_pca,y_train,y_test = train_test_split(X_pca,y,test_size=0.2,random_state=30)

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf=RandomForestClassifier()
model_rf.fit(X_train_pca,y_train)
model_rf.score(X_test_pca,y_test)
# Out:
# 0.712707182320442

# %%
import warnings
warnings.filterwarnings("ignore")
df.head(10).style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_ba6e3_row0_col0, #T_ba6e3_row7_col4 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_ba6e3_row0_col3, #T_ba6e3_row8_col3 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_ba6e3_row0_col4 {
#   background-color: #dd2a25;
#   color: #f1f1f1;
# }
# #T_ba6e3_row0_col5, #T_ba6e3_row0_col9, #T_ba6e3_row0_col11, #T_ba6e3_row1_col4, #T_ba6e3_row1_col5, #T_ba6e3_row2_col0, #T_ba6e3_row2_col5, #T_ba6e3_row2_col7, #T_ba6e3_row2_col9, #T_ba6e3_row2_col11, #T_ba6e3_row3_col5, #T_ba6e3_row4_col5, #T_ba6e3_row4_col9, #T_ba6e3_row4_col11, #T_ba6e3_row5_col5, #T_ba6e3_row5_col9, #T_ba6e3_row5_col11, #T_ba6e3_row6_col5, #T_ba6e3_row6_col9, #T_ba6e3_row6_col11, #T_ba6e3_row7_col3, #T_ba6e3_row7_col5, #T_ba6e3_row7_col9, #T_ba6e3_row7_col11, #T_ba6e3_row8_col0, #T_ba6e3_row8_col5, #T_ba6e3_row9_col5, #T_ba6e3_row9_col9, #T_ba6e3_row9_col11 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_ba6e3_row0_col7, #T_ba6e3_row1_col3, #T_ba6e3_row1_col11, #T_ba6e3_row3_col9, #T_ba6e3_row3_col11, #T_ba6e3_row4_col0, #T_ba6e3_row5_col4, #T_ba6e3_row7_col0, #T_ba6e3_row8_col9, #T_ba6e3_row8_col11 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_ba6e3_row1_col0 {
#   background-color: #d82422;
#   color: #f1f1f1;
# }
# #T_ba6e3_row1_col7 {
#   background-color: #c1161b;
#   color: #f1f1f1;
# }
# #T_ba6e3_row1_col9 {
#   background-color: #e32f27;
#   color: #f1f1f1;
# }
# #T_ba6e3_row2_col3, #T_ba6e3_row6_col3 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_ba6e3_row2_col4, #T_ba6e3_row3_col0, #T_ba6e3_row9_col0 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_ba6e3_row3_col3 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_ba6e3_row3_col4 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_ba6e3_row3_col7 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_ba6e3_row4_col3 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_ba6e3_row4_col4 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_ba6e3_row4_col7 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_ba6e3_row5_col0 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_ba6e3_row5_col3, #T_ba6e3_row9_col3 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_ba6e3_row5_col7, #T_ba6e3_row6_col7 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_ba6e3_row6_col0 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_ba6e3_row6_col4 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_ba6e3_row7_col7 {
#   background-color: #f24633;
#   color: #f1f1f1;
# }
# #T_ba6e3_row8_col4 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_ba6e3_row8_col7 {
#   background-color: #fc8060;
#   color: #f1f1f1;
# }
# #T_ba6e3_row9_col4 {
#   background-color: #e63328;
#   color: #f1f1f1;
# }
# #T_ba6e3_row9_col7 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# </style>
# <table id="T_ba6e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba6e3_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_ba6e3_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_ba6e3_level0_col2" class="col_heading level0 col2" >ChestPainType</th>
#       <th id="T_ba6e3_level0_col3" class="col_heading level0 col3" >RestingBP</th>
#       <th id="T_ba6e3_level0_col4" class="col_heading level0 col4" >Cholesterol</th>
#       <th id="T_ba6e3_level0_col5" class="col_heading level0 col5" >FastingBS</th>
#       <th id="T_ba6e3_level0_col6" class="col_heading level0 col6" >RestingECG</th>
#       <th id="T_ba6e3_level0_col7" class="col_heading level0 col7" >MaxHR</th>
#       <th id="T_ba6e3_level0_col8" class="col_heading level0 col8" >ExerciseAngina</th>
#       <th id="T_ba6e3_level0_col9" class="col_heading level0 col9" >Oldpeak</th>
#       <th id="T_ba6e3_level0_col10" class="col_heading level0 col10" >ST_Slope</th>
#       <th id="T_ba6e3_level0_col11" class="col_heading level0 col11" >HeartDisease</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba6e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba6e3_row0_col0" class="data row0 col0" >40</td>
#       <td id="T_ba6e3_row0_col1" class="data row0 col1" >M</td>
#       <td id="T_ba6e3_row0_col2" class="data row0 col2" >ATA</td>
#       <td id="T_ba6e3_row0_col3" class="data row0 col3" >140</td>
#       <td id="T_ba6e3_row0_col4" class="data row0 col4" >289</td>
#       <td id="T_ba6e3_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_ba6e3_row0_col6" class="data row0 col6" >Normal</td>
#       <td id="T_ba6e3_row0_col7" class="data row0 col7" >172</td>
#       <td id="T_ba6e3_row0_col8" class="data row0 col8" >N</td>
#       <td id="T_ba6e3_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_ba6e3_row0_col10" class="data row0 col10" >Up</td>
#       <td id="T_ba6e3_row0_col11" class="data row0 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ba6e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ba6e3_row1_col0" class="data row1 col0" >49</td>
#       <td id="T_ba6e3_row1_col1" class="data row1 col1" >F</td>
#       <td id="T_ba6e3_row1_col2" class="data row1 col2" >NAP</td>
#       <td id="T_ba6e3_row1_col3" class="data row1 col3" >160</td>
#       <td id="T_ba6e3_row1_col4" class="data row1 col4" >180</td>
#       <td id="T_ba6e3_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_ba6e3_row1_col6" class="data row1 col6" >Normal</td>
#       <td id="T_ba6e3_row1_col7" class="data row1 col7" >156</td>
#       <td id="T_ba6e3_row1_col8" class="data row1 col8" >N</td>
#       <td id="T_ba6e3_row1_col9" class="data row1 col9" >1.000000</td>
#       <td id="T_ba6e3_row1_col10" class="data row1 col10" >Flat</td>
#       <td id="T_ba6e3_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ba6e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ba6e3_row2_col0" class="data row2 col0" >37</td>
#       <td id="T_ba6e3_row2_col1" class="data row2 col1" >M</td>
#       <td id="T_ba6e3_row2_col2" class="data row2 col2" >ATA</td>
#       <td id="T_ba6e3_row2_col3" class="data row2 col3" >130</td>
#       <td id="T_ba6e3_row2_col4" class="data row2 col4" >283</td>
#       <td id="T_ba6e3_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_ba6e3_row2_col6" class="data row2 col6" >ST</td>
#       <td id="T_ba6e3_row2_col7" class="data row2 col7" >98</td>
#       <td id="T_ba6e3_row2_col8" class="data row2 col8" >N</td>
#       <td id="T_ba6e3_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_ba6e3_row2_col10" class="data row2 col10" >Up</td>
#       <td id="T_ba6e3_row2_col11" class="data row2 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ba6e3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ba6e3_row3_col0" class="data row3 col0" >48</td>
#       <td id="T_ba6e3_row3_col1" class="data row3 col1" >F</td>
#       <td id="T_ba6e3_row3_col2" class="data row3 col2" >ASY</td>
#       <td id="T_ba6e3_row3_col3" class="data row3 col3" >138</td>
#       <td id="T_ba6e3_row3_col4" class="data row3 col4" >214</td>
#       <td id="T_ba6e3_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_ba6e3_row3_col6" class="data row3 col6" >Normal</td>
#       <td id="T_ba6e3_row3_col7" class="data row3 col7" >108</td>
#       <td id="T_ba6e3_row3_col8" class="data row3 col8" >Y</td>
#       <td id="T_ba6e3_row3_col9" class="data row3 col9" >1.500000</td>
#       <td id="T_ba6e3_row3_col10" class="data row3 col10" >Flat</td>
#       <td id="T_ba6e3_row3_col11" class="data row3 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ba6e3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ba6e3_row4_col0" class="data row4 col0" >54</td>
#       <td id="T_ba6e3_row4_col1" class="data row4 col1" >M</td>
#       <td id="T_ba6e3_row4_col2" class="data row4 col2" >NAP</td>
#       <td id="T_ba6e3_row4_col3" class="data row4 col3" >150</td>
#       <td id="T_ba6e3_row4_col4" class="data row4 col4" >195</td>
#       <td id="T_ba6e3_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_ba6e3_row4_col6" class="data row4 col6" >Normal</td>
#       <td id="T_ba6e3_row4_col7" class="data row4 c

# %%
import missingno as msno
import matplotlib.pyplot as plt
msno.matrix(df)
plt.show()

# %%
import seaborn as sns
sns.countplot(x=df.HeartDisease)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='count'>

# %%
data_type = df.dtypes.value_counts()
plt.figure(figsize=(8,6))
data_type.plot(kind="bar",color="skyblue")
plt.title('Distribution of data Types in DataFrame')
plt.xlabel('Data Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
numerical = df.select_dtypes(include=['int64','float64']).columns
print(numerical)
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease'],
#       dtype='object')

# %%
categorical = df.select_dtypes(include=['object']).columns
print(categorical)
# Out:
# Index(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], dtype='object')

# %%
sns.pairplot(df,hue="HeartDisease",height=2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.histplot(data=df[df['HeartDisease'] == 0], x='Age', kde=True, color='blue', label='No Heart Disease')

sns.histplot(data=df[df['HeartDisease']==1],x='Age',kde=True,color='red',label='Heart Disease')
plt.title("Distribution of Age by Heart Disease")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid")
for column in df.columns:
    if column != 'HeartDisease':
        plt.figure(figsize=(10,6))
        
        if df[column].dtype == 'object':
            sns.countplot(data=df,x=column,hue="HeartDisease")
            plt.title(f'Comparison of {column} by Heart Disease')
            plt.xlabel(column)
            plt.ylabel('Count')
            plt.xticks(rotation=45)
            plt.legend()
            
        else:
            sns.boxplot(data=df,x='HeartDisease',y=column)
            plt.title(f'Comparison of {column} by Heart Disease')
            plt.xlabel('Heart Disease')
            plt.ylabel(column)
            
        plt.tight_layout()
        plt.show()

# %%
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111,projection='3d')

#scatter plot with age , cholesterol , and restingBP
ax.scatter(df['Age'],df['Cholesterol'],df['RestingBP'],c=df['HeartDisease'],cmap='coolwarm')
ax.set_xlabel('Age')
ax.set_ylabel("Cholesterol")
ax.set_zlabel("Resting BP")
ax.set_title("3D Scatter plot Age ,Cholesterol, and Resting BP")
plt.show()

sns.set(style="whitegrid")
plt.figure(figsize=(12,6))

sns.violinplot(data=df,x='HeartDisease',y='Age',palette="coolwarm",inner='quartile',cut=0)
sns.violinplot(data=df,x='HeartDisease',y='Cholesterol',palette="coolwarm",inner='quartile',cut=0)
sns.violinplot(data=df,x='HeartDisease',y='RestingBP',palette="coolwarm",inner='quartile',cut=0)
plt.xticks([0,1],['No Heart  Disease','Heart Disease'])
plt.xlabel('Heart Disease')
plt.ylabel('Value')
plt.title('Comparison of Age ,Cholesterol ,and Resting BP by Heart Disease')
plt.show()

# %%
selected_columns = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
df = df[selected_columns]
sns.set(style="whitegrid")

fig, axes = plt.subplots(5, 1, figsize=(6, 15))

# Plot box plots for Age, RestingBP, Cholesterol, MaxHR, and Oldpeak
sns.boxplot(data=df, y='Age', ax=axes[0], color='lightblue')
axes[0].set_title('Box Plot of Age')

sns.boxplot(data=df, y='RestingBP', ax=axes[1], color='lightgreen')
axes[1].set_title('Box Plot of Resting BP')

sns.boxplot(data=df, y='Cholesterol', ax=axes[2], color='lightcoral')
axes[2].set_title('Box Plot of Cholesterol')

sns.boxplot(data=df, y='MaxHR', ax=axes[3], color='lightsalmon')
axes[3].set_title('Box Plot of Max HR')

sns.boxplot(data=df, y='Oldpeak', ax=axes[4], color='lightpink')
axes[4].set_title('Box Plot of Oldpeak')
plt.tight_layout()
plt.show()

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix,annot=True ,cmap='coolwarm',vmin=-1,vmax=1)
plt.title('Correlation matrix')
plt.show()
